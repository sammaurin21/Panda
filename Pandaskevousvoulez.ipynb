# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
medecin = pd.read_csv("cmq.csv")

# %% [markdown]
# cellule sans code quand on va dans markdown pour cell

# %%
medecin
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %%
medecin.shape
# Out:
# (35109, 14)

# %%
medecin.head()
# Out:
#       num  annee   prenom      nom genre          specialite1 specialite2  \
# 0  #30001   1930   Lucien    Amyot     M  Médecine de famille         NaN
# 1  #30002   1930  Wilfrid    Audet     M             Inconnue         NaN
# 2  #30003   1930    A. T.  Batshaw     M  Médecine de famille         NaN
# 3  #30005   1930  Maurice  Beaudry     M         Dermatologie         NaN
# 4  #30006   1930    P. E.  Belleau     M     Médecine interne         NaN
#
#   specialite3              statut dateChangStatut typePermis     ville  \
# 0         NaN  Retrait pour décès      1981-12-29   Régulier  Montréal
# 1         NaN           Démission      1987-10-01   Régulier      Alma
# 2         NaN  Retrait pour décès      1983-11-11   Régulier  Montréal
# 3         NaN  Retrait pour décès      1989-02-12   Régulier    Québec
# 4         NaN  Retrait pour décès      1986-05-31   Régulier    Québec
#
#      prov    pays
# 0  Québec  Canada
# 1  Québec  Canada
# 2  Québec  Canada
# ...

# %%
medecin[1002:1010]
# Out:
#          num  annee       prenom               nom genre         specialite1  \
# 1002  #44050   1944  Jean-Benoit           Bechard     M  Chirurgie générale
# 1003  #44051   1944        H. F.          Brickman     F           Pédiatrie
# 1004  #44052   1944        E. R.  Mackenzie-Harpur     F  Biochimie médicale
# 1005  #44054   1944       Claude              Dubé     M       Ophtalmologie
# 1006  #44055   1944        Alban        Damphousse     M  Chirurgie générale
# 1007  #44056   1944     James L.         Mc Callum     M    Médecine interne
# 1008  #44057   1944    Samuel A.         Macdonald     M            Urologie
# 1009  #44061   1944         Léon           Leclerc     M            Inconnue
#
#                                             specialite2 specialite3  \
# 1002                                                NaN         NaN
# 1003                                                NaN         NaN
# 1004                                                NaN         NaN
# ...

# %%
medecin.loc

# %%
medecin.iloc[10000:10011,0:4]
# Out:
#           num  annee       prenom         nom
# 10000  #73357   1973       Pierre      Samson
# 10001  #73358   1973    Claudette       Soucy
# 10002  #73359   1973         Jean    Turcotte
# 10003  #73360   1973   Marie-José     Bernier
# 10004  #73361   1973     Francine      Allard
# 10005  #73362   1973      Éric N.        Gold
# 10006  #73363   1973       Lucile      Martin
# 10007  #73364   1973      Martine      Dozois
# 10008  #73365   1973      John W.    Sandison
# 10009  #73366   1973  Angela Lois    Sheppard
# 10010  #73367   1973        Denis  Provencher

# %%
medecin.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'specialite3', 'statut', 'dateChangStatut', 'typePermis', 'ville',
#        'prov', 'pays'],
#       dtype='object')

# %%
medecin.columns='num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
       'specialite3', 'statut', 'date', 'typePermis', 'ville',
       'prov', 'pays
# Out:
#   File "<ipython-input-18-4b38c526b004>", line 2
#     'specialite3', 'statut', 'date', 'typePermis', 'ville',
#     ^
# IndentationError: unexpected indent

# %%
medecin.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'specialite3', 'statut', 'dateChangStatut', 'typePermis', 'ville',
#        'prov', 'pays'],
#       dtype='object')

# %%
medecin.columns=['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
       'specialite3', 'statut', 'date', 'typePermis', 'ville',
       'prov', 'pays']

# %%
medecin.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'specialite3', 'statut', 'date', 'typePermis', 'ville', 'prov', 'pays'],
#       dtype='object')

# %%
medecin.count
# Out:
# <bound method DataFrame.count of           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %%
militaires = pd.read_csv("militaires.csv")

# %%
militaires
# Out:
#        annee  trimestre        date  \
# 0       2004          1  01-04-2004
# 1       2004          1  01-04-2004
# 2       2004          1  01-04-2004
# 3       2004          1  01-04-2004
# 4       2004          1  01-04-2004
# 5       2004          1  01-04-2004
# 6       2004          1  01-04-2004
# 7       2004          1  01-04-2004
# 8       2004          1  01-04-2004
# 9       2004          1  01-04-2004
# 10      2004          1  01-04-2004
# 11      2004          1  01-04-2004
# 12      2004          1  01-04-2004
# 13      2004          1  01-04-2004
# 14      2004          1  01-04-2004
# 15      2004          1  01-04-2004
# 16      2004          1  01-04-2004
# 17      2004          1  01-04-2004
# 18      2004          1  01-04-2004
# 19      2004          1  01-04-2004
# 20      2004          1  01-04-2004
# 21      2004          1  01-04-2004
# 22      2004          1  01-04-2004
# 23      2004          1  01-04-2004
# 24      2004          1  01-04-2004
# ...

# %%
militaires.montant.max()
# Out:
# 9500000.0

# %%
militaires.montant.min()
# Out:
# 0.0

# %%
militaires.sum()
# Out:
# annee                                                   27276835
# trimestre                                                  33852
# date           01-04-200401-04-200401-04-200401-04-200401-04-...
# fournisseur    JOHNSON CONTROLS LTD.Hewitt Rentals Inc.marlen...
# description    Services d'inspection et d'entretien des unité...
# montant                                              2.06471e+09
# dtype: object

# %%
militaires.montant.sum()
# Out:
# 2064712097.9099998

# %%
militaires.montant.average()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-790e443616e7> in <module>()
# ----> 1 militaires.montant.average()
#
# /home/ubuntu/miniconda3/envs/brassens/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'average'

# %%
medecin = pd.read_csv("cmq.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3bf22a7ec6f3> in <module>()
# ----> 1 medecin = pd.read_csv("cmq.csv")
#
# NameError: name 'pd' is not defined

# %%
medecin.genre.value_counts()/ len (medecin.genre)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bbc98dc0b6c8> in <module>()
# ----> 1 medecin.genre.value_counts()/ len (medecin.genre)*100
#
# NameError: name 'medecin' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dc23830fd0dd> in <module>()
# ----> 1 medecin
#
# NameError: name 'medecin' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-53110f6c4b11> in <module>()
# ----> 1 militaires
#
# NameError: name 'militaires' is not defined

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
medecin = pd.read_csv("cmq.csv")

# %%
medecin
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %%
medecin.genre.value_counts()
# Out:
# M    22441
# F    12668
# Name: genre, dtype: int64

# %%
militaires = pd.read_csv("militaires.csv")

# %%
militaires
# Out:
#        annee  trimestre        date  \
# 0       2004          1  01-04-2004
# 1       2004          1  01-04-2004
# 2       2004          1  01-04-2004
# 3       2004          1  01-04-2004
# 4       2004          1  01-04-2004
# 5       2004          1  01-04-2004
# 6       2004          1  01-04-2004
# 7       2004          1  01-04-2004
# 8       2004          1  01-04-2004
# 9       2004          1  01-04-2004
# 10      2004          1  01-04-2004
# 11      2004          1  01-04-2004
# 12      2004          1  01-04-2004
# 13      2004          1  01-04-2004
# 14      2004          1  01-04-2004
# 15      2004          1  01-04-2004
# 16      2004          1  01-04-2004
# 17      2004          1  01-04-2004
# 18      2004          1  01-04-2004
# 19      2004          1  01-04-2004
# 20      2004          1  01-04-2004
# 21      2004          1  01-04-2004
# 22      2004          1  01-04-2004
# 23      2004          1  01-04-2004
# 24      2004          1  01-04-2004
# ...

# %%
militaires.fournisseur
# Out:
# 0                                    JOHNSON CONTROLS LTD.
# 1                                      Hewitt Rentals Inc.
# 2                             marlene hurley brandy hurley
# 3                                       Levitt-Safety Ltd.
# 4                                       I S E Research Ltd
# 5                                               Cyberguard
# 6                                   LOS ALTOS TECHNOLOGIES
# 7                                       FOSTER-MILLER INC.
# 8                                     EADS Astrium Limited
# 9        Ranco Controls Canada Limited, CompAir Canada ...
# 10                                         BDI Canada  Inc
# 11                                          Nautel Limited
# 12                                Edmonton Gear Centre Ltd
# 13                                 A P M DIESEL (1992) INC
# 14                 DEW Engineering and Development Limited
# 15                                           HADIA IBRAHIM
# ...

# %%
militaires.groupby("fournisseur").montant.sum()
# Out:
# fournisseur
# "TOI TOI Systemy Sanitarni" Ltd.                               152436.30
# "Vernon Ship Supplies, Inc."                                    23590.00
# "Y. Fukunaga Products, Ltd"                                     53102.25
# (Clare) Weber's Fabricating Ltd.                                39448.00
# (D.T.) Secure Technologies International Inc.                   18511.00
# 01dB-METRAVIB                                                   23140.00
# 0714576 B.C ltd                                                 11459.00
# 0772497 BC LTD                                                 136399.20
# 0863183 B.C. Ltd.                                              340000.00
# 101003979 SASKATCHEWAN LTD.                                     16423.00
# 1070449 ontario limited                                         25303.00
# 1075776 Ontario Inc.                                            44726.00
# 1078845 Ontario Inc.                                            27731.00
# ...

# %%
militaires.groupby("fournisseur").montant.sum().sort_values(ascending=False)
# Out:
# fournisseur
# UNITED STATES DEPARTMENT OF THE AIR FORCE (AFSAC)             18458629.00
# Skylink Aviation Inc                                          18429545.14
# SkyLink Aviation Inc.                                         18091044.31
# SKYLINK AVIATION                                              17559538.80
# SIMEX DEFENCE INC. / DEFENSE SIMEX INC.                       16242356.00
# UNITED STATES DEPARTMENT OF THE ARMY (USASAC)                 15741157.00
# Calian Ltd                                                    15244855.53
# SkyLink Aviation                                              13431716.30
# Hewlett-Packard (Canada) Co. Hewlett-Packard (Canada) Cie     12727054.00
# UNITED STATES DEPARTMENT OF THE AIR FORCE (AFSAT)             11819634.00
# Caspian Projects Inc                                          11579442.00
# THALES CANADA INC.                                            11341356.00
# ...

# %%
medecin.statut.value_counts()
# Out:
# Inscrit - Actif                                            21017
# Démission                                                   4623
# Retrait pour décès                                          3877
# Inscrit - Retraité                                          2415
# Radié pour non paiement de cotisation                       2085
# Expiration                                                   630
# Inscrit - Actif (l'exercice de ce membre est limité)         184
# Radié pour non-paiement de cotisation                         88
# Inscrit - Retraité (l'exercice de ce membre est limité)       71
# Radié                                                         67
# Retrait                                                       29
# Inscrit - Inactif                                             10
# Non inscrit                                                    9
# Révocation                                                     4
# Name: statut, dtype: int64

# %%
rad = medecin.statut == "Radié"
medecin[rad]
# Out:
#           num  annee       prenom            nom genre  \
# 1375   #48004   1948     Alphonse        Bardari     M
# 1661   #49130   1949      Jacques      Pettigrew     M
# 2512   #53150   1953        J.-C.       Paquette     M
# 2761   #54174   1954     Philippe       Moreault     M
# 3057   #55201   1955       Claude  Saint-Laurent     M
# 3087   #55234   1955      Thérèse        Leclerc     F
# 3253   #56099   1956      Gilbert        Michaud     M
# 4220   #59188   1959        Lloyd         Alford     M
# 4483   #60125   1960      Jeannot          Houle     M
# 4801   #61113   1961      Noël R.       Kaufmann     M
# 4840   #61157   1961         Jack           Blum     M
# 4957   #61325   1961       Gérard       Monfette     M
# 5129   #62157   1962       Andrée        Lessard     F
# 5250   #62290   1962         Yvon       Scheffer     M
# 5590   #63290   1963  Albert Ross           Deep     M
# 6096   #65137   1965       Claude        Leclair     M
# ...

# %%
medecin[rad].genre.value_counts()
# Out:
# M    61
# F     6
# Name: genre, dtype: int64

# %%
doctlab = medecin.nom == "Labrèche"
medecin[doctlab]
# Out:
#           num  annee   prenom       nom genre         specialite1 specialite2  \
# 23527  #97250   1997  Jacques  Labrèche     M  Chirurgie générale         NaN
#
#       specialite3           statut dateChangStatut typePermis          ville  \
# 23527         NaN  Inscrit - Actif             NaN   Régulier  Drummondville
#
#          prov    pays
# 23527  Québec  Canada

# %%
actifs = medecin.statut.str.contains("Actif")

# %%
medecin.pays.value_counts()
# Out:
# Canada                 32737
# États-Unis              1405
# Inconnu                  608
# France                    78
# Royaume-Uni               68
# Liban                     35
# Suisse                    20
# Espagne                   15
# Australie                 12
# Israël                    11
# Irlande                    9
# Allemagne                  8
# Émirats arabes unis        8
# Haïti                      6
# Kenya                      5
# Arabie Saoudite            5
# Mexique                    5
# Hong Kong                  4
# Brésil                     4
# Nouvelle-Zélande           4
# Inde                       4
# Singapour                  3
# Afrique du Sud             3
# Belgique                   3
# Chine                      3
# Syrie                      3
# Italie                     3
# Bermudes                   3
# Pays-Bas                   2
# Grèce                      2
# Suède                      2
# Danemark                   2
# ...

# %%
medecin[actifs].pays.value_counts()
# Out:
# Canada                 20973
# États-Unis               162
# France                    17
# Liban                     11
# Suisse                     6
# Émirats arabes unis        5
# Australie                  3
# Bermudes                   3
# Royaume-Uni                2
# Haïti                      2
# Afrique du Sud             2
# Israël                     2
# Chine                      2
# Maroc                      1
# Arabie Saoudite            1
# Syrie                      1
# Brésil                     1
# Cambodge                   1
# Nouvelle-Zélande           1
# Îles Cayman                1
# Singapour                  1
# Irlande                    1
# Barbade                    1
# Kenya                      1
# Name: pays, dtype: int64

# %%
famille = medecin.specialite1 == "Médecine de famille"
medecin[famille]
# Out:
#           num  annee                  prenom                nom genre  \
# 0      #30001   1930                  Lucien              Amyot     M
# 2      #30003   1930                   A. T.            Batshaw     M
# 5      #30008   1930                  Antoni              Blais     M
# 6      #30012   1930                    Lyla              Brown     F
# 9      #30017   1930                    Rémi         Desjardins     M
# 12     #30024   1930                   I. M.           Gauthier     M
# 14     #30029   1930                  Pierre             Jodoin     M
# 16     #30032   1930                 J.-Paul           Laplante     M
# 20     #30045   1930                  Marthe            Pelland     F
# 22     #30048   1930                  Lucien         Petitclerc     M
# 23     #30050   1930                   L. P.           Poliquin     M
# 24     #30052   1930                 Antonio             Robert     M
# ...

# %%
medecin[famille].genre.value_counts()
# Out:
# M    6980
# F    6170
# Name: genre, dtype: int64

# %%
medecin[famille & actifs].genre.value_counts()
# Out:
# F    5610
# M    4497
# Name: genre, dtype: int64

# %%
avant1960 = medecin.annee < 1960
medecin[avant1960]
# Out:
#          num  annee                 prenom           nom genre  \
# 0     #30001   1930                 Lucien         Amyot     M
# 1     #30002   1930                Wilfrid         Audet     M
# 2     #30003   1930                  A. T.       Batshaw     M
# 3     #30005   1930                Maurice       Beaudry     M
# 4     #30006   1930                  P. E.       Belleau     M
# 5     #30008   1930                 Antoni         Blais     M
# 6     #30012   1930                   Lyla         Brown     F
# 7     #30014   1930               Alphonse     Couturier     M
# 8     #30015   1930                    Guy  D'Argencourt     M
# 9     #30017   1930                   Rémi    Desjardins     M
# 10    #30020   1930                 Armand      Frappier     M
# 11    #30021   1930                 Edmour      Frenette     M
# 12    #30024   1930                  I. M.      Gauthier     M
# 13    #30028   1930                  J. A.        Hébert     M
# ...

# %%
medecin[famille & actifs].genre.value_counts()
# Out:
# F    5610
# M    4497
# Name: genre, dtype: int64

# %%
medecin[famille & actifs].genre.value_counts().plot()

# %%
medecin[famille & actifs].genre.value_counts().plot(kind="pie")

# %%
medecin[famille & actifs].genre.value_counts().plot(kind="pie",title="Genre de médecin actifs au Québec")

# %%
medecin.annee.hist()

# %%
medecin.annee.hist(bins=87)

# %%
medecin.annee.hist(bins=9)

# %%
medecin.groupby("genre").annee.hist(bins=87,alpha=0.5)
# Out:
# genre
# F    Axes(0.125,0.125;0.775x0.755)
# M    Axes(0.125,0.125;0.775x0.755)
# Name: annee, dtype: object

# %%
medecin.groupby("genre").annee.hist(bins=87)
# Out:
# genre
# F    Axes(0.125,0.125;0.775x0.755)
# M    Axes(0.125,0.125;0.775x0.755)
# Name: annee, dtype: object

# %%
militaires.montant.sum()
# Out:
# 2064712097.9099998

# %%
militaires.groupby("annee").montant.sum()
# Out:
# annee
# 2004    2.669878e+08
# 2005    3.897053e+08
# 2006    1.936317e+08
# 2007    1.189116e+08
# 2008    6.558974e+07
# 2009    8.243240e+07
# 2010    5.385913e+07
# 2011    2.023364e+08
# 2012    1.212093e+08
# 2013    1.528981e+08
# 2014    6.264056e+07
# 2015    2.487403e+08
# 2016    1.057698e+08
# Name: montant, dtype: float64

# %%
militaires.groupby("annee").montant.sum().plot()

# %%
militaires.groupby("annee").montant.sum().plot(kind="barh")

# %%
militaires.groupby("annee").montant.sum().plot(kind="barh",color="pink")
